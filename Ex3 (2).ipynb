# %% [markdown]
# <a href="https://colab.research.google.com/github/subi-147/TimeSeries_lab/blob/main/TSA_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

def plot_time_series(data):
    plt.figure(figsize=(10,6))
    plt.plot(data)
    plt.title('Time Series Plot')
    plt.xlabel('Time')
    plt.ylabel('Value')
    plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf

def plot_acf_series(data):
    plt.figure(figsize=(10,6))
    plot_acf(data, lags=40)
    plt.title('Autocorrelation Plot')
    plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(data):
    result = adfuller(data)
    print("ADF Statistic: %f" % result[0])
    print("p-value: %f" % result[1])

    if result[1] <= 0.05:
        print("The series is stationary (reject null hypothesis)")
    else:
        print("The series is non-stationary (fail to reject null hypothesis)")

# %%
from statsmodels.tsa.stattools import kpss

def kpss_test(data):
    result = kpss(data, regression='c')
    print("KPSS Statistic: %f" % result[0])
    print("p-value: %f" % result[1])

    if result[1] <= 0.05:
        print("The series is non-stationary (reject null hypothesis)")
    else:
        print("The series is stationary (fail to reject null hypothesis)")

# %%
import numpy as np
import pandas as pd

# Example: Create a random time series data (Non-stationary)
np.random.seed(42)
time_series_data = pd.Series(np.random.randn(100).cumsum())

# Visual inspection
plot_time_series(time_series_data)
plot_acf_series(time_series_data)

# Statistical Tests
print("Performing ADF Test:")
adf_test(time_series_data)

print("\nPerforming KPSS Test:")
kpss_test(time_series_data)
# Out:
# Performing ADF Test:
# ADF Statistic: -1.358332
# p-value: 0.602081
# The series is non-stationary (fail to reject null hypothesis)
#
# Performing KPSS Test:
# KPSS Statistic: 1.257304
# p-value: 0.010000
# The series is non-stationary (reject null hypothesis)
# <ipython-input-10-29242a43db5c>:4: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(data, regression='c')
